# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/stock_prices.csv')
df.head()
# Out:
#          date  price
# 0  2023-01-01   2.97
# 1  2023-01-02   6.13
# 2  2023-01-03   8.40
# 3  2023-01-04   9.69
# 4  2023-01-05   9.51

# %%
plt.plot(df.index, df['price'])
plt.show()
